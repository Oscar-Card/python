# %% [markdown]
# **Finding the Top Rated Movie Directors**

# %% [markdown]
# **data source(s):**
#
# https://pybit.es/codechallenge13.html
#
# https://nycdatascience.com/blog/student-works/web-scraping/movie-rating-prediction/

# %% [markdown]
# Using the data on IMDB movies located at the following url,
#
# -obtain the 20 highest rated movie directors based on their average movie IMDB ratings.
#
# -Only consider directors with a minimum of 4 movies, otherwise you get misrepresentative data.
# Take movies of year >= 1960.
#
# -Print the top 20 highest rated directors with their movies ordered desc on rating

# %%
import pandas as pd
dataUrl = 'https://raw.githubusercontent.com/sundeepblue/movie_rating_prediction/master/movie_metadata.csv'
data = pd.read_csv(dataUrl)
data.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
# 2                 11000.0  200074175.0        Action|Adventure|Thriller  ...
# 3                 27000.0  448130642.0                  Action|Thriller  ...
# 4                   131.0          NaN                      Documentary  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
# 1               1238.0  English      USA           PG-13  300000000.0
# 2                994.0  English       UK           PG-13  245000000.0
# 3               2701.0  English      USA           PG-13  250000000.0
# 4                  NaN      NaN      NaN             NaN          NaN
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# 1      2007.0                 5000.0        7.1          2.35
# 2      2015.0                  393.0        6.8          2.35
# 3      2012.0                23000.0        8.5          2.35
# 4         NaN                   12.0        7.1           NaN
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
#
# [5 rows x 28 columns]

# %%
#Year filter
data = data[data['title_year']>=1960]
data.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 5  Color     Andrew Stanton                   462.0     132.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 5                    475.0                   530.0   Samantha Morton
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
# 2                 11000.0  200074175.0        Action|Adventure|Thriller  ...
# 3                 27000.0  448130642.0                  Action|Thriller  ...
# 5                   640.0   73058679.0          Action|Adventure|Sci-Fi  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
# 1               1238.0  English      USA           PG-13  300000000.0
# 2                994.0  English       UK           PG-13  245000000.0
# 3               2701.0  English      USA           PG-13  250000000.0
# 5                738.0  English      USA           PG-13  263700000.0
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# 1      2007.0                 5000.0        7.1          2.35
# 2      2015.0                  393.0        6.8          2.35
# 3      2012.0                23000.0        8.5          2.35
# 5      2012.0                  632.0        6.6          2.35
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 5                24000
#
# [5 rows x 28 columns]

# %%
#director name count

x= data.director_name.value_counts()
x
# Out:
# Steven Spielberg    26
# Woody Allen         22
# Clint Eastwood      20
# Martin Scorsese     20
# Ridley Scott        17
#                     ..
# Stuart Hazeldine     1
# James Fargo          1
# Hue Rhodes           1
# Scott Alexander      1
# Kriv Stenders        1
# Name: director_name, Length: 2357, dtype: int64

# %%
# filter for director name with a minimum of 4 movies

x[x>=4]
x
# Out:
# Steven Spielberg    26
# Woody Allen         22
# Clint Eastwood      20
# Martin Scorsese     20
# Ridley Scott        17
#                     ..
# Stuart Hazeldine     1
# James Fargo          1
# Hue Rhodes           1
# Scott Alexander      1
# Kriv Stenders        1
# Name: director_name, Length: 2357, dtype: int64

# %%
# Listing movie director name
list(x[x>=4].keys())
# Out:
# ['Steven Spielberg',
#  'Woody Allen',
#  'Clint Eastwood',
#  'Martin Scorsese',
#  'Ridley Scott',
#  'Steven Soderbergh',
#  'Tim Burton',
#  'Spike Lee',
#  'Renny Harlin',
#  'Oliver Stone',
#  'Sam Raimi',
#  'Michael Bay',
#  'Robert Rodriguez',
#  'Barry Levinson',
#  'Robert Zemeckis',
#  'Joel Schumacher',
#  'Ron Howard',
#  'John Carpenter',
#  'Brian De Palma',
#  'Kevin Smith',
#  'Richard Donner',
#  'Tony Scott',
#  'Peter Jackson',
#  'Wes Craven',
#  'Shawn Levy',
#  'Rob Cohen',
#  'Richard Linklater',
#  'Rob Reiner',
#  'Stephen Frears',
#  'Francis Ford Coppola',
#  'Chris Columbus',
#  'Brett Ratner',
#  'David Fincher',
#  'Paul W.S. Anderson',
#  'Bobby Farrelly',
#  'John McTiernan',
#  'Phillip Noyce',
#  'Kenneth Branagh',
#  'M. Night Shyamalan',
#  'Danny Boyle',
#  'George A. Romero',
#  'Tyler Perry',
#  'Dennis Dugan',
#  'Lasse Hallström',
#  'Martin Campbell',
#  'Sam Mendes',
#  'Roland Emmerich',
#  'Antoine Fuqua',
#  'Ivan Reitman',
#  'F. Gary Gray',
#  'Jay Roach',
#  'Adam Shankman',
#  'Harold Ramis',
#  'Quentin Tarantino',
#  'Marc Forster',
#  'Yimou Zhang',
#  'Jaume Collet-Serra',
#  'Zack Snyder',
#  'Ang Lee',
#  'Frank Coraci',
#  'David Gordon Green',
#  'Christopher Nolan',
#  'Donald Petrie',
#  'Edward Zwick',
#  'George Miller',
#  'Bryan Singer',
#  'Frank Oz',
#  'James Mangold',
#  'Simon West',
#  'Stephen Herek',
#  'Garry Marshall',
#  'David O. Russell',
#  'Neil Jordan',
#  'Guy Ritchie',
#  'Joe Wright',
#  'Doug Liman',
#  'Peter Segal',
#  'Cameron Crowe',
#  'Jon Favreau',
#  'Paul Greengrass',
#  'Mike Newell',
#  'Terry Gilliam',
#  'Joe Dante',
#  'Malcolm D. Lee',
#  'James Wan',
#  'Gore Verbinski',
#  'James Cameron',
#  'Paul McGuigan',
#  'Paul Schrader',
#  'Michael Winterbottom',
#  'Tom Shadyac',
#  'Wolfgang Petersen',
#  'David Cronenberg',
#  'Barry Sonnenfeld',
#  'Tobe Hooper',
#  'Todd Phillips',
#  'Roger Donaldson',
#  'Stanley Kubrick',
#  'Catherine Hardwicke',
#  'Jon Turteltaub',
#  'William Friedkin',
#  'Mel Brooks',
#  'James Ivory',
#  'Louis Leterrier',
#  'Ethan Coen',
#  'Gus Van Sant',
#  'Wes Anderson',
#  'David Ayer',
#  'John Singleton',
#  'Roman Polanski',
#  'Paul Verhoeven',
#  'Peter Berg',
#  'David R. Ellis',
#  'Jonathan Liebesman',
#  'Stephen Hopkins',
#  'Raja Gosnell',
#  'Lana Wachowski',
#  'Jason Reitman',
#  'Mark Waters',
#  'Brian Levant',
#  'Tim Story',
#  'Timur Bekmambetov',
#  'Guy Hamilton',
#  'Andy Tennant',
#  'Gary Fleder',
#  'Brian Robbins',
#  'Adam McKay',
#  'Chuck Russell',
#  'Michael Apted',
#  'John Woo',
#  'Robert Luketic',
#  'McG',
#  'Taylor Hackford',
#  'Andy Fickman',
#  'Curtis Hanson',
#  'Atom Egoyan',
#  'Darren Aronofsky',
#  'Mike Nichols',
#  'Michael Moore',
#  'Michael Mann',
#  'Bill Condon',
#  'Robert Schwentke',
#  'Paul Thomas Anderson',
#  'Peter Hyams',
#  'Paul Weitz',
#  'Alejandro G. Iñárritu',
#  'Sydney Pollack',
#  'Steve Miner',
#  'John Frankenheimer',
#  'Richard LaGravenese',
#  'John Whitesell',
#  'Norman Jewison',
#  'Stephen Daldry',
#  'Les Mayfield',
#  'Lawrence Kasdan',
#  'Richard Lester',
#  'Tom Tykwer',
#  'Nicholas Stoller',
#  'Larry Charles',
#  'Sidney Lumet',
#  'Kenny Ortega',
#  'Andrzej Bartkowiak',
#  'Brad Bird',
#  'Jon M. Chu',
#  'Robert Redford',
#  'Mark Neveldine',
#  'Peter Cattaneo',
#  'Kevin Reynolds',
#  'Peter Chelsom',
#  'Jan de Bont',
#  'Nicole Holofcener',
#  'Guillermo del Toro',
#  'Rod Lurie',
#  'Andrew Adamson',
#  'Scott Derrickson',
#  'Miguel Arteta',
#  'John Glen',
#  'Jean-Pierre Jeunet',
#  'Neil Burger',
#  'Andrew Niccol',
#  'Gary Winick',
#  'Nancy Meyers',
#  'Eric Darnell',
#  'Anne Fletcher',
#  'Rob Zombie',
#  'Mira Nair',
#  'Luc Besson',
#  'Wayne Wang',
#  'John Lee Hancock',
#  'Judd Apatow',
#  'Lee Tamahori',
#  'John Madden',
#  'Darren Lynn Bousman',
#  'Tim Hill',
#  'Uwe Boll',
#  'Mike Leigh',
#  'Michael Polish',
#  "Gavin O'Connor",
#  'Rob Minkoff',
#  'Ben Stiller',
#  'Kirk Jones',
#  'Alfred Hitchcock',
#  'David Koepp',
#  'Brad Anderson',
#  'Paul Feig',
#  'D.J. Caruso',
#  'Baz Luhrmann',
#  'Chris Weitz',
#  'David Lynch',
#  'Rob Marshall',
#  'Francis Lawrence',
#  'Harold Becker',
#  'George Lucas',
#  'John Lasseter',
#  'Scott Hicks',
#  'Justin Lin',
#  'Jonathan Demme',
#  'Alexander Payne',
#  'David Zucker',
#  'Brian Helgeland',
#  'John Landis',
#  'Alex Proyas',
#  'George Clooney',
#  'Martin Brest',
#  'Terence Young',
#  'Nicolas Winding Refn',
#  'Mike Mitchell',
#  'Peter Howitt',
#  'James Gray',
#  'John Milius',
#  'Roland Joffé',
#  'Ken Kwapis',
#  'Dennie Gordon',
#  'Jon Amiel',
#  'Rob Letterman',
#  'Ronny Yu',
#  'Jean-Jacques Annaud',
#  'Rob Bowman',
#  'Jay Chandrasekhar',
#  'Jonathan Levine',
#  'Frank Darabont',
#  'David Dobkin',
#  'Randall Wallace',
#  'Oliver Parker',
#  'Jay Duplass',
#  'Terrence Malick',
#  'Peter Hewitt',
#  'Michel Gondry',
#  'Amy Heckerling',
#  'Iain Softley',
#  'Andrew Fleming',
#  'Patrick Lussier',
#  'Christopher McQuarrie',
#  'Tim Johnson',
#  'Mark L. Lester',
#  'Roger Spottiswoode',
#  'Sam Peckinpah',
#  'Steven Brill',
#  'Rick Famuyiwa',
#  'Craig Gillespie',
#  'Hugh Wilson',
#  'Jaume Balagueró',
#  'Richard Attenborough',
#  'John Erick Dowdle',
#  'Jake Kasdan',
#  'John Stockwell',
#  'Hayao Miyazaki',
#  'Shane Meadows',
#  'James McTeigue',
#  'David Bowers',
#  'Bruce Beresford',
#  'David Wain',
#  'Joseph Kosinski',
#  'Angelina Jolie Pitt',
#  'Andrew Davis',
#  'Sergio Leone',
#  'Bille Woodruff',
#  'James Wong',
#  'Walter Hill',
#  'David Twohy',
#  'Adrian Lyne',
#  'Jeff Nichols',
#  'Joss Whedon',
#  'John Sayles',
#  'John Dahl',
#  'Vincenzo Natali',
#  'Ron Shelton',
#  'Russell Mulcahy',
#  'Peyton Reed',
#  'Gabriele Muccino',
#  'Alexandre Aja',
#  'Paul Haggis',
#  'Tarsem Singh',
#  'Sam Weisman',
#  'Michael Caton-Jones',
#  'John Moore',
#  'Rawson Marshall Thurber',
#  'George Tillman Jr.',
#  'Bob Clark',
#  'Simon Wincer',
#  'Alejandro Amenábar',
#  'Steve Carr',
#  'Keenen Ivory Wayans',
#  'Edgar Wright',
#  'Albert Hughes',
#  'Steve Oedekerk',
#  'Spike Jonze',
#  'Joe Johnston',
#  'Jonathan Frakes',
#  'Matthew Vaughn',
#  'Alex Kendrick',
#  'Jeff Tremaine',
#  'David Frankel',
#  'Mike Judge',
#  'Sean Anders',
#  'Peter Weir',
#  'Sofia Coppola',
#  'Jason Friedberg',
#  'Christopher Guest',
#  'Burr Steers',
#  'Alfonso Cuarón',
#  'Gavin Hood',
#  'Dean Parisot',
#  'Carlos Saldanha',
#  'Matt Reeves',
#  'Pierre Morel',
#  'Jim Sheridan',
#  'J.J. Abrams',
#  'Joel Coen',
#  'Edward Burns',
#  'Mikael Håfström',
#  'Penny Marshall',
#  'Kimberly Peirce',
#  'Anthony Russo',
#  'Phil Lord',
#  'Nick Cassavetes',
#  'Betty Thomas',
#  'Brad Silberling',
#  'Luke Greenfield',
#  'Jonathan Lynn',
#  'Julie Taymor',
#  'Jonathan Mostow',
#  'Frank Marshall',
#  'David Yates',
#  'Walt Becker',
#  'Irwin Winkler',
#  'Stephen Sommers']

# %%
selected = data.loc[data.director_name.isin(list(x[x>=4].keys()))]

# %%
selected.groupby('director_name')['imdb_score'].mean().sort_values(ascending=False).head(20)
# Out:
# director_name
# Sergio Leone             8.475000
# Christopher Nolan        8.425000
# Hayao Miyazaki           8.225000
# Quentin Tarantino        8.200000
# Stanley Kubrick          8.000000
# Frank Darabont           7.975000
# Joss Whedon              7.925000
# James Cameron            7.914286
# Alfonso Cuarón           7.800000
# Alejandro G. Iñárritu    7.783333
# David Fincher            7.750000
# Peter Weir               7.725000
# Peter Jackson            7.675000
# Martin Scorsese          7.660000
# Matthew Vaughn           7.650000
# David Lynch              7.640000
# Wes Anderson             7.628571
# Richard Attenborough     7.600000
# Edgar Wright             7.600000
# Paul Haggis              7.600000
# Name: imdb_score, dtype: float64
