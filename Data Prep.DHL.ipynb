# %% [markdown]
# **Technical Exercise**

# %%
# Importing excel file

import pandas as pd
import numpy as np
missing_value= ["n/a", "na", "--", "PrivacySuppressed", "privacysupressed"]
df = pd.read_excel('/Users/leonardo/Dropbox/Suffolk_MSBA/DHL/Cut_Data_12.1.21_to_2.28.22.xlsx', sheet_name='Dataset_1',na_values = missing_value)
df.head()
# Out:
#    Order Number Purchase Order    Ship To Address  ord line      item  \
# 0    2092690050     5826051280  WALMART HVDC 7016         2  41912000
# 1    2092690050     5826051280  WALMART HVDC 7016         1   1368000
# 2    2092690050     5826051280  WALMART HVDC 7016         3  46813000
# 3    2092690050     5826051280  WALMART HVDC 7016         4  15242000
# 4    2092690050     5826051280  WALMART HVDC 7016         5  16474000
#
#                          Description  customer line ord qty  line ord qty  \
# 0  BGLS CRSPY CORN SNCKS ORIG VAL SZ                   32.0            32
# 1   CM SVRY SNCK MX BOLD PARTY BLEND                  180.0           180
# 2           GARD SR RYE CHIPS GARLIC                  120.0             0
# 3     BC FRT ROLLUPS JOLLY RCHR 20CT                  105.0           105
# 4     BC FRU PIZZA PEEL N BUILD 20CT                  105.0            11
#
#    adj qty  ship qty    cut reason             cut date cut time       user  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65500 entries, 0 to 65499
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order Number           65500 non-null  int64
#  1   Purchase Order         65500 non-null  object
#  2   Ship To Address        65500 non-null  object
#  3   ord line               65500 non-null  int64
#  4   item                   65500 non-null  int64
#  5   Description            65500 non-null  object
#  6   customer line ord qty  65450 non-null  float64
#  7   line ord qty           65500 non-null  int64
#  8   adj qty                65450 non-null  float64
#  9   ship qty               65500 non-null  int64
#  10  cut reason             7672 non-null   object
#  11  cut date               7672 non-null   object
#  12  cut time               7672 non-null   object
#  13  user                   7672 non-null   object
# ...

# %%
df.shape
# Out:
# (65500, 18)

# %% [markdown]
# **Filtering Data.**
#
# <u>Dataset_1<u>
#
# Excluding 'Ship To Address' = 'FAKE CUSTOMER'

# %%
df_filtered = df[(df['Ship To Address']!='FAKE CUSTOMER')]
df_filtered.head()
# Out:
#    Order Number Purchase Order    Ship To Address  ord line      item  \
# 0    2092690050     5826051280  WALMART HVDC 7016         2  41912000
# 1    2092690050     5826051280  WALMART HVDC 7016         1   1368000
# 2    2092690050     5826051280  WALMART HVDC 7016         3  46813000
# 3    2092690050     5826051280  WALMART HVDC 7016         4  15242000
# 4    2092690050     5826051280  WALMART HVDC 7016         5  16474000
#
#                          Description  customer line ord qty  line ord qty  \
# 0  BGLS CRSPY CORN SNCKS ORIG VAL SZ                   32.0            32
# 1   CM SVRY SNCK MX BOLD PARTY BLEND                  180.0           180
# 2           GARD SR RYE CHIPS GARLIC                  120.0             0
# 3     BC FRT ROLLUPS JOLLY RCHR 20CT                  105.0           105
# 4     BC FRU PIZZA PEEL N BUILD 20CT                  105.0            11
#
#    adj qty  ship qty    cut reason             cut date cut time       user  \
# ...

# %%
df_filtered.shape
# Out:
# (65500, 18)

# %%
import pandas as pd
import numpy as np
missing_value= ["n/a", "na", "--", "PrivacySuppressed", "privacysupressed"]
df2 = pd.read_excel('/Users/leonardo/Dropbox/Suffolk_MSBA/DHL/Cut_Data_12.1.21_to_2.28.22.xlsx', sheet_name='Dataset_2',na_values = missing_value)
df2.head()
# Out:
#    Order Number Purchase Order        Ship To Address  ord line       item  \
# 0    2092808371       5MWW64NN  HSE1 AMAZON FRESH (H)        23  149901000
# 1    2092808371       5MWW64NN  HSE1 AMAZON FRESH (H)        24  149401000
# 2    2092808371       5MWW64NN  HSE1 AMAZON FRESH (H)        25  110163000
# 3    2092808371       5MWW64NN  HSE1 AMAZON FRESH (H)        26   12593000
# 4    2092808371       5MWW64NN  HSE1 AMAZON FRESH (H)        27   12479000
#
#                            Description  customer line ord qty  line ord qty  \
# 0     AH ORG VEGAN MAC PSTA SC CHEDDAR                   28.0            28
# 1  AH ORG CHDR BUNNIES BKD SNCK CRCKRS                   36.0            36
# 2    PRO LT SOUP CREAMY CHICKEN NOODLE                  224.0           224
# 3  GMI CINNAMON TOAST CRUNCH CEREAL LS                  252.0           252
# 4    GMI HONEY NUT CHEERIOS CEREAL MID                   80.0            80
#
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65500 entries, 0 to 65499
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order Number           65500 non-null  int64
#  1   Purchase Order         65500 non-null  object
#  2   Ship To Address        65500 non-null  object
#  3   ord line               65500 non-null  int64
#  4   item                   65500 non-null  int64
#  5   Description            65500 non-null  object
#  6   customer line ord qty  65457 non-null  float64
#  7   line ord qty           65500 non-null  int64
#  8   adj qty                65457 non-null  float64
#  9   ship qty               65500 non-null  int64
#  10  cut reason             6719 non-null   object
#  11  cut date               6719 non-null   object
#  12  cut time               6719 non-null   object
#  13  user                   6719 non-null   object
# ...

# %%
df2.shape
# Out:
# (65500, 18)

# %% [markdown]
# **Filtering Data.**
#
# <u>Dataset_2<u>
#
# Excluding 'Ship To Address' = 'FAKE CUSTOMER'

# %%
df2_filtered = df2[(df2['Ship To Address']!='FAKE CUSTOMER')]
df2_filtered.head()
# Out:
#    Order Number Purchase Order        Ship To Address  ord line       item  \
# 0    2092808371       5MWW64NN  HSE1 AMAZON FRESH (H)        23  149901000
# 1    2092808371       5MWW64NN  HSE1 AMAZON FRESH (H)        24  149401000
# 2    2092808371       5MWW64NN  HSE1 AMAZON FRESH (H)        25  110163000
# 3    2092808371       5MWW64NN  HSE1 AMAZON FRESH (H)        26   12593000
# 4    2092808371       5MWW64NN  HSE1 AMAZON FRESH (H)        27   12479000
#
#                            Description  customer line ord qty  line ord qty  \
# 0     AH ORG VEGAN MAC PSTA SC CHEDDAR                   28.0            28
# 1  AH ORG CHDR BUNNIES BKD SNCK CRCKRS                   36.0            36
# 2    PRO LT SOUP CREAMY CHICKEN NOODLE                  224.0           224
# 3  GMI CINNAMON TOAST CRUNCH CEREAL LS                  252.0           252
# 4    GMI HONEY NUT CHEERIOS CEREAL MID                   80.0            80
#
# ...

# %%
df2_filtered.shape
# Out:
# (65500, 18)

# %% [markdown]
# **Filtering Data.**
#
# <u>Dataset_3<u>
#
# Excluding 'Ship To Address' = 'FAKE CUSTOMER'

# %%
import pandas as pd
import numpy as np
missing_value= ["n/a", "na", "--", "PrivacySuppressed", "privacysupressed"]
df3 = pd.read_excel('/Users/leonardo/Dropbox/Suffolk_MSBA/DHL/Cut_Data_12.1.21_to_2.28.22.xlsx', sheet_name='Dataset_3',na_values = missing_value)
df3.head()
# Out:
#    Order Number Purchase Order             Ship To Address  ord line  \
# 0  2.092829e+09     9676146445  WAL-MART DC 6080A-ASM DIST      18.0
# 1  2.092829e+09     9676146445  WAL-MART DC 6080A-ASM DIST      19.0
# 2  2.092829e+09     9676146445  WAL-MART DC 6080A-ASM DIST      20.0
# 3  2.092829e+09     9676146445  WAL-MART DC 6080A-ASM DIST      21.0
# 4  2.092829e+09     9676146445  WAL-MART DC 6080A-ASM DIST       1.0
#
#           item                              Description  \
# 0   49934000.0  BC BISQUICK HEART SMART PNCK BKG MX 6PK
# 1  110151000.0    OEP SNS TACO SHELLS HINT OF LIME 10CT
# 2  110739000.0      CF ORG CHWY GRAN BARS VAN CHIP 10CT
# 3  110932000.0         LB KID BARS CHOC CHIP COOKIE 6CT
# 4  189107000.0           PRO BREAD CRUMBS ITALIAN STYLE
#
#    customer line ord qty  line ord qty  adj qty  ship qty    cut reason  \
# 0                   30.0          30.0      0.0      30.0           NaN
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43716 entries, 0 to 43715
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order Number           43342 non-null  float64
#  1   Purchase Order         43342 non-null  object
#  2   Ship To Address        43716 non-null  object
#  3   ord line               43342 non-null  float64
#  4   item                   43342 non-null  float64
#  5   Description            43342 non-null  object
#  6   customer line ord qty  43283 non-null  float64
#  7   line ord qty           43342 non-null  float64
#  8   adj qty                43283 non-null  float64
#  9   ship qty               43329 non-null  float64
#  10  cut reason             5336 non-null   object
#  11  cut date               5336 non-null   object
#  12  cut time               5336 non-null   object
#  13  user                   5336 non-null   object
# ...

# %%
df3.shape
# Out:
# (43716, 18)

# %%
df3_filtered = df3[(df3['Ship To Address']!='FAKE CUSTOMER')]
df3_filtered.head()
# Out:
#    Order Number Purchase Order             Ship To Address  ord line  \
# 0  2.092829e+09     9676146445  WAL-MART DC 6080A-ASM DIST      18.0
# 1  2.092829e+09     9676146445  WAL-MART DC 6080A-ASM DIST      19.0
# 2  2.092829e+09     9676146445  WAL-MART DC 6080A-ASM DIST      20.0
# 3  2.092829e+09     9676146445  WAL-MART DC 6080A-ASM DIST      21.0
# 4  2.092829e+09     9676146445  WAL-MART DC 6080A-ASM DIST       1.0
#
#           item                              Description  \
# 0   49934000.0  BC BISQUICK HEART SMART PNCK BKG MX 6PK
# 1  110151000.0    OEP SNS TACO SHELLS HINT OF LIME 10CT
# 2  110739000.0      CF ORG CHWY GRAN BARS VAN CHIP 10CT
# 3  110932000.0         LB KID BARS CHOC CHIP COOKIE 6CT
# 4  189107000.0           PRO BREAD CRUMBS ITALIAN STYLE
#
#    customer line ord qty  line ord qty  adj qty  ship qty    cut reason  \
# 0                   30.0          30.0      0.0      30.0           NaN
# ...

# %%
df3_filtered.shape
# Out:
# (43342, 18)

# %%
# Downloading file for Presentation

df3_filtered.to_excel("/Users/leonardo/Dropbox/Suffolk_MSBA/DHL/NO_FAKE_CUST_DATASET.xlsx")

# %%
df4_unionall = pd.concat([df_filtered,df2_filtered,df3_filtered], ignore_index=True)
df4_unionall.head()
# Out:
#    Order Number Purchase Order    Ship To Address  ord line        item  \
# 0  2.092690e+09     5826051280  WALMART HVDC 7016       2.0  41912000.0
# 1  2.092690e+09     5826051280  WALMART HVDC 7016       1.0   1368000.0
# 2  2.092690e+09     5826051280  WALMART HVDC 7016       3.0  46813000.0
# 3  2.092690e+09     5826051280  WALMART HVDC 7016       4.0  15242000.0
# 4  2.092690e+09     5826051280  WALMART HVDC 7016       5.0  16474000.0
#
#                          Description  customer line ord qty  line ord qty  \
# 0  BGLS CRSPY CORN SNCKS ORIG VAL SZ                   32.0          32.0
# 1   CM SVRY SNCK MX BOLD PARTY BLEND                  180.0         180.0
# 2           GARD SR RYE CHIPS GARLIC                  120.0           0.0
# 3     BC FRT ROLLUPS JOLLY RCHR 20CT                  105.0         105.0
# 4     BC FRU PIZZA PEEL N BUILD 20CT                  105.0          11.0
#
#    adj qty  ship qty    cut reason             cut date cut time       user  \
# ...

# %%
df4_unionall.shape
# Out:
# (174342, 18)

# %%
# Downloading file to build the Dashboard

df3_filtered.to_excel("/Users/leonardo/Dropbox/Suffolk_MSBA/DHL/DATASET_for_Dashboard.xlsx")
